# %%
# Standard imports
import numpy as np

# pertpy is needed to download the Kang data
import pertpy
import scanpy as sc

# This will download the data to ./data/kang_2018.h5ad
adata = pertpy.data.kang_2018()
# Store counts separately in the layers
adata.layers["counts"] = adata.X.copy()

# %%
import matplotlib.pyplot as plt

adata.layers["diff"] = np.random.randn(*adata.shape)
sel_gene = "TNFRSF18"

fsize = plt.rcParams["figure.figsize"]
fig = plt.figure(figsize=(fsize[0] * 3, fsize[1]))
axs = [fig.add_subplot(1, 3, i + 1) for i in range(3)]
for ax in axs:
    ax.set_aspect("equal")
sc.pl.umap(
    adata,
    layer="diff",
    color=[sel_gene],
    cmap=plt.get_cmap("seismic"),
    vcenter=0,
    vmin=-0.5,
    vmax=0.5,
    title="Pred diff (stim - ctrl)",
    ax=axs[0],
    show=False,
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 8
#       6 fsize = plt.rcParams['figure.figsize']
#       7 fig = plt.figure(figsize=(fsize[0] * 3, fsize[1]))
# ----> 8 axs = [fig.add_subplot(1, 3, i+1, squeeze=False) for i in range(3)]
#       9 for ax in axs:
#      10     ax.set_aspect('equal')
#
# Cell In[33], line 8, in <listcomp>(.0)
#       6 fsize = plt.rcParams['figure.figsize']
#       7 fig = plt.figure(figsize=(fsize[0] * 3, fsize[1]))
# ----> 8 axs = [fig.add_subplot(1, 3, i+1, squeeze=False) for i in range(3)]
#       9 for ax in axs:
#      10     ax.set_aspect('equal')
#
# File ~/prog/python/pyLemur/.venv/lib/python3.11/site-packages/matplotlib/figure.py:782, in FigureBase.add_subplot(self, *args, **kwargs)
#     780         args = tuple(map(int, str(args[0])))
#     781     projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 782     ax = projection_class(self, *args, **pkw)
#     783     key = (projection_class, pkw)
#     784 return self._add_axes_internal(ax, key)
#
# File ~/prog/python/pyLemur/.venv/lib/python3.11/site-packages/matplotlib/axes/_base.py:692, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, *args, **kwargs)
#     689 if yscale:
#     690     self.set_yscale(yscale)
# --> 692 self._internal_update(kwargs)
#     694 for name, axis in self._axis_map.items():
#     695     axis.callbacks._connect_picklable(
#     696         'units', self._unit_change_handler(name))
#
# File ~/prog/python/pyLemur/.venv/lib/python3.11/site-packages/matplotlib/artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File ~/prog/python/pyLemur/.venv/lib/python3.11/site-packages/matplotlib/artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: Axes.set() got an unexpected keyword argument 'squeeze'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 sc.pl.__panel_grid
#
# AttributeError: module 'scanpy.plotting' has no attribute '__panel_grid'

# %%
sc.pl.umap(
    adata,
    layer="diff",
    color=[sel_gene, "YBEY"],
    cmap=plt.get_cmap("seismic"),
    vcenter=0,
    vmin=-0.5,
    vmax=0.5,
    title="Pred diff (stim - ctrl)",
    show=False,
)
# Out:
# WARNING: The title list is shorter than the number of panels. Using 'color' value instead for some plots.
# [<Axes: title={'center': 'Pred diff (stim - ctrl)'}, xlabel='UMAP1', ylabel='UMAP2'>,
#  <Axes: title={'center': 'YBEY'}, xlabel='UMAP1', ylabel='UMAP2'>]

# %%
adata.var_names
# Out:
# Index(['AL627309.1', 'RP11-206L10.2', 'RP11-206L10.9', 'FAM87B', 'LINC00115',
#        'FAM41C', 'NOC2L', 'KLHL17', 'PLEKHN1', 'RP11-54O7.17',
#        ...
#        'LSS', 'MCM3AP-AS1', 'MCM3AP', 'AP001469.9', 'YBEY', 'C21orf58', 'PCNT',
#        'DIP2A', 'S100B', 'PRMT2'],
#       dtype='object', name='index', length=15706)
